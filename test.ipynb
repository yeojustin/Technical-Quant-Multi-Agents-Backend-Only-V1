# %%
import pandas_ta as ta
import pandas as pd
import yfinance as yf

# %%
def map_timeframe_to_yf(timeframe: str) -> tuple[str, str]:
    tf = timeframe.lower()
    if tf == "4h": return "730d", "60m"
    elif tf == "1d": return "10y", "1d"
    elif tf == "1w": return "10y", "1wk"
    elif tf == "1m": return "10y", "1mo"
    elif tf == "1q": return "10y", "3mo"
    return "5y", "1d"

# %%
def fetch_data(ticker: str, timeframe: str) -> pd.DataFrame:
    period, interval = map_timeframe_to_yf(timeframe)
    df = yf.download(ticker, period=period, interval=interval, progress=False)
    if df.empty:
        raise ValueError("No data found.")
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = df.columns.droplevel(1)
    return df

# %%
fetch_data('AAPL', '1h')
# Out:
# Price            Close        High         Low        Open    Volume
# Date
# 2021-06-04  122.711517  122.974705  120.723023  120.937469  75169300
# 2021-06-07  122.721260  123.130654  121.678276  122.984440  71057600
# 2021-06-08  123.540062  125.216644  123.023445  123.403597  74403800
# 2021-06-09  123.920197  124.524545  123.325597  123.998178  56877900
# 2021-06-10  122.925972  124.953458  122.760266  123.812992  71186400
# ...                ...         ...         ...         ...       ...
# 2026-05-28  312.510010  312.799988  309.570007  310.679993  48220400
# 2026-05-29  312.059998  315.000000  309.529999  311.779999  70026800
# 2026-06-01  306.309998  310.940002  305.019989  309.630005  48849900
# 2026-06-02  315.200012  315.450012  306.690002  307.459991  44534700
# 2026-06-03  310.260010  316.940002  308.850006  314.174988  50459550
#
# [1255 rows x 5 columns]
